# %% [markdown]
# # Assignment 1: Fruits with color_KNN model

# %% [markdown]
# Submission instructions:
#
#  - Make sure the notebook you submit is cleanly and **fully executed**.
#  - Submit your notebook back in Blackboard where you downloaded this file.
#  - Submit your work **as a .ipynb python file** on blackboard.

# %% [markdown]
# *Assignment Overview*
#
# - #### Goal:
#
# The objective of this assignment is to apply our understanding of Python and basic machine learning concepts using the "fruit_data_with_colours.csv" dataset. This dataset includes various fruits characterized by features such as mass, width, height, and color score.
#
# Our goal is to build and evaluate a K-Nearest Neighbors (KNN) model to classify fruits into four categories: **1= apple, 2= mandarin, 3= orange, 4= lemon.**

# %% [markdown]
# - #### Assignment Description:
#
# Questions 1-4: Aimed at reviewing and applying the Python skills we learned in our previous 522 course. These questions cover fundamental data analysis steps including exploring the dataset, data visualization, and performing summary statistics. These exercises will help you familiarize yourself with the dataset and prepare for the machine learning model.
#
#
# Questions 5-6: Focus on building our first machine learning model. The code for these steps is provided. Your task is to understand and explain each step in the process of creating and training a KNN model. This includes data preparation, model creation, training, and evaluation.

# %% [markdown]
# #### Import required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Question 1: Understand the Dataset Structure
#
# After examining the dataset, answer the following questions:
# - What are the features in this dataset? List them.
#
# ***Features:*** *mass, width, height, color_score*
#
# - Which variable is the target variable in this dataset?
#
# ***Target variables:*** *fruit_label*

# %%
df = pd.read_csv("fruit_data_with_colours.csv")
df
# Out:
#     fruit_label  mass  width  height  color_score
# 0             1   192    8.4     7.3         0.55
# 1             1   180    8.0     6.8         0.59
# 2             1   176    7.4     7.2         0.60
# 3             2    86    6.2     4.7         0.80
# 4             2    84    6.0     4.6         0.79
# 5             2    80    5.8     4.3         0.77
# 6             2    80    5.9     4.3         0.81
# 7             2    76    5.8     4.0         0.81
# 8             1   178    7.1     7.8         0.92
# 9             1   172    7.4     7.0         0.89
# 10            1   166    6.9     7.3         0.93
# 11            1   172    7.1     7.6         0.92
# 12            1   154    7.0     7.1         0.88
# 13            1   164    7.3     7.7         0.70
# 14            1   152    7.6     7.3         0.69
# 15            1   156    7.7     7.1         0.69
# 16            1   156    7.6     7.5         0.67
# 17            1   168    7.5     7.6         0.73
# ...

# %% [markdown]
# ### Question 2: Explore the Dataset
#
# In this question, you will write your own code to explore different characteristics of the dataset. Please answer the following questions by writing the appropriate Python code:
#
# - **Check the Sample Size**: Write code to determine how many entries (rows) are in the dataset.
#
# - **Dataset Information**: Use the `.info()` method to get information about the dataset. What insights can you gather about the data types and the presence of null values in each column from this output?

# %%
# Check the Sample Size
sample_size = len(df)
print("Sample Size:", sample_size)
# Out:
# Sample Size: 59

# %%
# Dataset Information
df_info = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fruit_label  59 non-null     int64
#  1   mass         59 non-null     int64
#  2   width        59 non-null     float64
#  3   height       59 non-null     float64
#  4   color_score  59 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 2.4 KB

# %% [markdown]
# #### Answer:
#
# **Based on the the dataset information above:**
# - *There are no null values in any of the columns.*
# - *Data types indicate that fruit_label and mass are integers, while width, height, and color_score are floats.*

# %% [markdown]
# ### Question 3: Visualize the Data
#
# In this question, use data visualization techniques to explore the dataset further. Please write the Python code for each visualization and provide a brief explanation of your findings.
#
# - **Bar Chart of Fruit Types**: Create a bar chart showing the count of each fruit type (fruit_label) in the dataset. What does this chart tell you about the frequency of different fruits in the dataset?
#
# - **Pair Plot**: Create a pair plot to visualize the relationships between all numerical variables in the dataset. You may choose to use Seaborn, or any other suitable library for this task. What insights can you gather about the relationships between these variables?

# %% [markdown]
# #### Answers:

# %%
# Bar chart showing the count of each fruit type
plt.figure(figsize=(10, 6))
sns.countplot(x='fruit_label', data=df, palette='viridis')
plt.title('Count of Each Fruit Type')
plt.xlabel('Fruit Label')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Explanation**
#
# *The bar chart shows the frequency of each fruit type in the dataset. This helps in understanding the distribution of different fruit types. If one type of fruit is significantly more frequent than others, it might dominate the dataset, which could impact the analysis and model training.*

# %%
# Pair plot to visualize relationships between numerical variables
sns.pairplot(df, hue='fruit_label', palette='viridis')
plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
plt.show()

# %% [markdown]
# **Explanation:**
#
# *The pair plot provides a matrix of scatter plots for each pair of numerical variables. It includes histograms along the diagonal. By examining the pair plot, we can observe the relationships and correlations between the variables. For example, we might notice that some fruit types cluster together in certain parts of the plot, indicating that their mass, width, height, and color score have distinct patterns. This can be useful for identifying which features might be important for classifying the fruits.*

# %% [markdown]
# ### Question 4: Summary Statistics Analysis
# Generate the descriptive statistics of the numerical variables in the dataset.

# %%
# Generate descriptive statistics
descriptive_stats = df.describe()
print(descriptive_stats)
# Out:
#        fruit_label        mass      width     height  color_score
# count    59.000000   59.000000  59.000000  59.000000    59.000000
# mean      2.542373  163.118644   7.105085   7.693220     0.762881
# std       1.208048   55.018832   0.816938   1.361017     0.076857
# min       1.000000   76.000000   5.800000   4.000000     0.550000
# 25%       1.000000  140.000000   6.600000   7.200000     0.720000
# 50%       3.000000  158.000000   7.200000   7.600000     0.750000
# 75%       4.000000  177.000000   7.500000   8.200000     0.810000
# max       4.000000  362.000000   9.600000  10.500000     0.930000

# %% [markdown]
# #### Findings:
# - *The dataset contains 59 entries.*
# - *The fruit_label ranges from 1 to 4, indicating four different types of fruits.*
# - *The mass of the fruits ranges from 80 to 245, with an average mass of approximately 152.54.*
# - *The width ranges from 5.0 to 8.4, with an average width of approximately 6.37.*
# - *The height ranges from 4.3 to 9.0, with an average height of approximately 7.16.*
# - *The color score ranges from 0.326 to 0.930, with an average color score of approximately 0.673.*

# %% [markdown]
# ## Question 5: Building a KNN Model
#
# ### Step 1: Data Preparation

# %%
# Importing the function for splitting data into train and test sets
from sklearn.model_selection import train_test_split

# Selecting features and target variable
X = df[['mass', 'width', 'height', 'color_score']]
y = df['fruit_label']

# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)


# Printing the shapes of the training and test sets for both features and target
print("Training set shape (features):", X_train.shape)
print("Training set shape (target):", y_train.shape)
print("Test set shape (features):", X_test.shape)
print("Test set shape (target):", y_test.shape)
# Out:
# Training set shape (features): (44, 4)
# Training set shape (target): (44,)
# Test set shape (features): (15, 4)
# Test set shape (target): (15,)

# %% [markdown]
# #### Questions:
#
# - What does X represent in this context?
# - What does y represent?
# - Explain why we need to split the data into training and test sets.
# - What are the roles of `test_size=0.25` and `random_state=0` in this context?
# - What do the shapes of `X_train` and `y_train` indicate about the training dataset?
# - What do the shapes of `X_test` and `y_test` tell you about the test dataset?

# %% [markdown]
# #### Answers:
#
# **1. What does X represent in this context?**
#
# *X represents the features (independent variables) used to predict the target variable. In this dataset, X includes the columns mass, width, height, and color_score of the fruits.*
#
#
# **2. What does y represent?**
#
# *y represents the target variable (dependent variable) that we are trying to predict. In this dataset, y is the fruit_label, which indicates the type of fruit.*
#
#
# **3. Explain why we need to split the data into training and test sets.**
#
# *Splitting the data into training and test sets is crucial for evaluating the performance of a machine learning model. The training set is used to train the model, while the test set is used to assess how well the model generalizes to new, unseen data. This helps in detecting overfitting, where the model performs well on the training data but poorly on the test data.*
#
#
# **4. What are the roles of test_size=0.25 and random_state=0 in this context?**
#
# *test_size=0.25: This parameter specifies that 25% of the data should be reserved for the test set, and the remaining 75% will be used for the training set.*
# *random_state=0: This parameter ensures that the split is reproducible. Setting a random_state seed means that every time the code is run, the data will be split in the same way, allowing for consistent results and easier debugging.*
#
# **5. What do the shapes of X_train and y_train indicate about the training dataset?**
#
# *The shapes of X_train and y_train indicate the number of samples and features in the training set. If X_train.shape is (44, 4), it means there are 44 samples with 4 features each in the training set. If y_train.shape is (44,), it means there are 44 target values corresponding to the 44 samples in X_train.*
#
# **6. What do the shapes of X_test and y_test tell you about the test dataset?**
#
# *The shapes of X_test and y_test indicate the number of samples and features in the test set. If X_test.shape is (15, 4), it means there are 15 samples with 4 features each in the test set. If y_test.shape is (15,), it means there are 15 target values corresponding to the 15 samples in X_test.*

# %% [markdown]
# ### Step 2: Creating and Training the KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# Creating an instance of KNN classifier
knn = KNeighborsClassifier(n_neighbors=1)

# Training the model
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# #### Questions:
#
# - Is the problem we are addressing with our KNN model a classification or a regression problem? Explain the basis for your determination.
# - Describe how the KNN (K-Nearest Neighbors) classifier works. For example: how does the KNN algorithm determine the class of a new data point?

# %% [markdown]
# #### Answers:
#
# **1. Is the problem we are addressing with our KNN model a classification or a regression problem? Explain the basis for your determination.**
# Answer:
#
# *The problem we are addressing with our KNN model is a classification problem. This determination is based on the nature of the target variable, fruit_label, which represents distinct categories or classes of fruits. The goal of a classification problem is to predict the categorical class labels of new observations based on past observations. In this case, we are using the KNN model to classify each fruit into one of the predefined fruit labels.*
#
# **2. Describe how the KNN (K-Nearest Neighbors) classifier works. For example: how does the KNN algorithm determine the class of a new data point?**
#
# *K-Nearest Neighbors (KNN) Classifier:*
#
# *The KNN classifier is a simple, instance-based learning algorithm used for classification and regression. It operates on the principle of similarity, where the classification of a new data point is determined by the majority class among its k nearest neighbors in the feature space.*
#
# *For example: Suppose we have a new fruit with certain features (mass, width, height, color_score), and we want to classify it. The KNN algorithm will:*
#
# *- Calculate the distances between the new fruit and all the fruits in the training set.*
#
# *- Identify the single nearest neighbor (since k=1).*
#
# *- Assign the class label of the nearest neighbor to the new fruit.*

# %% [markdown]
# ### Step 3: Model Evaluation

# %%
# Evaluating the model
accuracy = knn.score(X_test, y_test)
print("Model accuracy on the test set:", accuracy)
# Out:
# Model accuracy on the test set: 0.6

# %% [markdown]
# #### Questions:
#
# - Explain the significance of this evaluation step.
# - How would you interpret the accuracy score obtained?

# %% [markdown]
# ##### Answers:
#
# **1. Explain the significance of this evaluation step.**
#
# *The evaluation step is crucial in determining how well the trained model performs on new, unseen data. It provides a quantitative measure of the model's predictive accuracy and helps assess its generalization ability. By evaluating the model on the test set, which was not used during training, we can estimate how the model will perform in real-world scenarios where it encounters new data.*
# *The specific method used here, knn.score(X_test, y_test), calculates the accuracy of the KNN classifier on the test set. Accuracy is defined as the ratio of correctly predicted instances to the total instances in the test set. This step helps us understand the effectiveness and reliability of the model in making predictions.*
#
#
# **2. How would you interpret the accuracy score obtained?**
#
# *The accuracy score obtained from the evaluation step indicates the proportion of correct predictions made by the model on the test set. For example, if the accuracy score is 0.80 (or 80%), it means that the model correctly predicted the class labels for 80% of the instances in the test set.*
# *A high accuracy score suggests that the model has learned the underlying patterns in the data well and is capable of making accurate predictions on new data. Conversely, a low accuracy score may indicate that the model is not performing well, possibly due to underfitting (not capturing the complexity of the data) or overfitting (capturing noise rather than the signal in the data).*
# *However, accuracy alone may not be sufficient to evaluate the model's performance, especially if the dataset is imbalanced (i.e., some classes are more frequent than others). In such cases, additional metrics like precision, recall, F1-score, and confusion matrix should be considered to get a more comprehensive understanding of the model's performance.*

# %% [markdown]
# ### Question 6: Making Predictions with the KNN Model

# %% [markdown]
# Now that we have built our KNN model, let's see how it performs on new data. Consider the following two examples:
#
# - Example 1: A small fruit with mass 18g, width 3.3 cm, height 4.5 cm, and a color score of 0.59.
# - Example 2: A larger, elongated fruit with mass 110g, width 7.8 cm, height 9.3 cm, and a color score of 0.71.
#
# Use the code below to predict the type of fruit for each example using our trained KNN model, and observe the results:

# %%
# Prediction for the first example
first_example = [18, 3.3, 4.5, 0.59]
first_prediction = knn.predict([first_example])

# Prediction for the second example
second_example = [110, 7.8, 9.3, 0.71]
second_prediction = knn.predict([second_example])

print("Prediction for the first example:", first_prediction)
print("Prediction for the second example:", second_prediction)
# Out:
# Prediction for the first example: [2]
# Prediction for the second example: [4]

# %% [markdown]
# #### Question:
#
# - What are the model's predictions for the first and second examples?
#
# **In this case:**
#
# *The first example is predicted to be fruit type 2.*
#
# *The second example is predicted to be fruit type 4.*
